# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
request = requests.get('https://pokemondb.net/pokedex/all')

# %%
soup = BeautifulSoup(request.text, 'html.parser')

# %%
names = set()
for tag in soup.find_all(class_ = 'ent-name'):
    names.add(tag.text.lower())

# %%
bad_names = ['tapu lele','mr. mime','flabébé','nidoran♂',"sirfetch'd",'tapu fini',
             'mime jr.','tapu bulu','type: null','nidoran♀','tapu koko','mr. rime']
good_names = ['tapu-lele','mr-mime','flabebe','nidoran-m','sirfetchd','tapu-fini',
              'mime-jr','tapu-bulu','type-null','nidoran-f','tapu-koko','mr-rime']

# %%
for bad,good in zip(bad_names,good_names):
    names.remove(bad)
    names.add(good)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24104/2683911044.py in <module>
#       5
#       6 for bad,good in zip(bad_names,good_names):
# ----> 7     names.remove(bad)
#       8     names.add(good)
#
# KeyError: 'tapu lele'

# %%
len(names) # number of pokemon 898
# Out:
# 898

# %%
import time

replace_dict = {
#     '<img alt="Physical"':'physical<img alt="Physical"',
#     '<img alt="Special"':'special<img alt="Special"',
#     '<img alt="Status"':'status<img alt="Status"',
    '<img class="img-fixed" src="https://img.pokemondb.net/images/icons/move-physical.png" width="30" height="20" alt="Physical" title="Physical" loading="lazy">':'physical',
    '<img class="img-fixed" src="https://img.pokemondb.net/images/icons/move-special.png" width="30" height="20" alt="Special" title="Special" loading="lazy">':'special',
    '<img class="img-fixed" src="https://img.pokemondb.net/images/icons/move-status.png" width="30" height="20" alt="Status" title="Status" loading="lazy">':'status'
}

def get_move_data(names):
    data = {}
    for i,name in enumerate(names):
        if i != 0 and i % 50 == 0:
            print(i)
            time.sleep(10)
        url = 'https://pokemondb.net/pokedex/' + name
        request = requests.get(url)
        text = request.text
        for key, val in replace_dict.items():
            text = text.replace(key,val)
        move_tables = pd.read_html(text, attrs={'class':'data-table'})
        data[name] = move_tables
    return data

# %%
move_data = get_move_data(names)
# Out:
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850

# %%
# print bad names (names with no data) if there are any
for key,val in move_data.items():
    if not len(val):
        print(key,val)

# %%
# print names with any NaNs in Cat. column
for name, tables in move_data.items():
    for table in tables:
        if table['Cat.'].isna().sum() != 0:
            print(name)

# %%
final_move_data = {}
for name,tables in move_data.items():
    for i,table in enumerate(tables):
        if i == 0:
            temp_table = table.copy()
        else:
            temp_table = pd.concat([temp_table,table.copy()],axis=0,ignore_index=True)
    combined_table = temp_table.drop_duplicates(ignore_index=True)
    combined_table['Name'] = name
    final_move_data[name] = combined_table
# Out:
# C:\Users\aaron\AppData\Local\Temp/ipykernel_24104/3464085293.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_table['Name'] = name

# %%
list(final_move_data.items())[3][1]
# Out:
#       Lv.         Move    Type      Cat. Power Acc.     TM  TR      Name
# 0     1.0   Poison Gas  Poison    status     —   90    NaN NaN  salandit
# 1     1.0      Scratch  Normal  physical    40  100    NaN NaN  salandit
# 2     5.0         Smog  Poison   special    30   70    NaN NaN  salandit
# 3    10.0        Ember    Fire   special    40  100    NaN NaN  salandit
# 4    15.0  Poison Fang  Poison  physical    50  100    NaN NaN  salandit
# ..    ...          ...     ...       ...   ...  ...    ...  ..       ...
# 104   NaN   Poison Jab  Poison  physical    80  100   84.0 NaN  salandit
# 105   NaN      Swagger  Normal    status     —   85   87.0 NaN  salandit
# 106   NaN   Sleep Talk  Normal    status     —    —   88.0 NaN  salandit
# 107   NaN   Substitute  Normal    status     —    —   90.0 NaN  salandit
# 108   NaN      Confide  Normal    status     —    —  100.0 NaN  salandit
#
# [109 rows x 9 columns]

# %%
# combine all pokemon tables into one
for i,(name,table) in enumerate(final_move_data.items()):
    if i == 0:
        temp_table = table.copy()
    else:
        temp_table = pd.concat([temp_table,table.copy()],axis=0,ignore_index=True)

# %%
temp_table.isna().sum()
# Out:
# Lv.        69525
# Move           0
# Type           0
# Cat.           0
# Power          0
# Acc.           0
# Name           0
# TM         46224
# Method     84511
# TR         75850
# Details    87614
# dtype: int64

# %%
names_list = list(names.copy())
bad_names_list = list(names.copy())
for bad,good in zip(bad_names,good_names):
    idx = bad_names_list.index(good)
    bad_names_list[idx] = bad

# %%
for a, b in zip(names_list, bad_names_list):
    print(a,b)
# Out:
# scatterbug scatterbug
# zangoose zangoose
# volcarona volcarona
# salandit salandit
# eldegoss eldegoss
# ekans ekans
# drizzile drizzile
# nidoran-m nidoran♂
# pyroar pyroar
# growlithe growlithe
# zubat zubat
# togekiss togekiss
# trubbish trubbish
# simipour simipour
# pidove pidove
# clefairy clefairy
# applin applin
# venonat venonat
# azelf azelf
# piloswine piloswine
# cherubi cherubi
# inkay inkay
# greedent greedent
# polteageist polteageist
# dracovish dracovish
# snorlax snorlax
# rhyperior rhyperior
# swoobat swoobat
# virizion virizion
# cutiefly cutiefly
# dragalge dragalge
# moltres moltres
# sealeo sealeo
# absol absol
# mantyke mantyke
# furfrou furfrou
# spinda spinda
# remoraid remoraid
# rayquaza rayquaza
# darmanitan darmanitan
# eevee eevee
# slurpuff slurpuff
# corvisquire corvisquire
# crawdaunt crawdaunt
# talonflame talonflame
# gurdurr gurdurr
# hoppip hoppip
# natu natu
# scolipede scolipede
# gliscor gliscor
# arrokuda arrokuda
# seedot seedot
# gible gible
# quilladin quilladin
# shelmet shelmet
# aegislash aegislash
# honedge honedge
# lunala lunala
# piplup piplup
# emolga emolga
# golett golett
# gumshoos gumshoos
# floatzel floatzel
# venipede venipede
# serperior serperior
# venomoth venomoth
# grumpig grumpig
# gothorita gothorita
# blacephalon blacephalon
# bayleef bayleef
# glaceon glaceon
# yveltal yveltal
# solgaleo solgaleo
# ninjask ninjask
# sigilyph sigilyph
# silicobra silicobra
# zacian zacian
# machop machop
# runerigus runerigus
# shelgon shelgon
# umbreon umbreon
# palpitoad palpitoad
# electrode electrode
# zorua zorua
# drilbur drilbur
# kyogre kyogre
# golurk golurk
# infernape infernape
# amoonguss amoonguss
# lopunny lopunny
# combusken combusken
# masquerain masquerain
# nuzleaf nuzleaf
# sizzlipede sizzlipede
# spritzee spritzee
# combee combee
# regirock regirock
# beedrill beedrill
# krookodile krookodile
# exploud exploud
# wailord wailord
# trumbeak trumbeak
# chespin chespin
# salamence salamence
# marill marill
# yanma yanma
# smoochum smoochum
# manaphy manaphy
# abra abra
# toxel toxel
# misdreavus misdreavus
# bulbasaur bulbasaur
# pidgeotto pidgeotto
# kubfu kubfu
# beldum beldum
# relicanth relicanth
# qwilfish qwilfish
# abomasnow abomasnow
# spinarak spinarak
# registeel registeel
# rattata rattata
# darkrai darkrai
# bronzong bronzong
# charjabug charjabug
# miltank miltank
# stoutland stoutland
# graveler graveler
# espurr espurr
# munchlax munchlax
# cresselia cresselia
# tropius tropius
# mienshao mienshao
# stunky stunky
# blissey blissey
# delcatty delcatty
# zebstrika zebstrika
# brionne brionne
# chimchar chimchar
# makuhita makuhita
# forretress forretress
# politoed politoed
# numel numel
# ledian ledian
# aggron aggron
# manectric manectric
# bastiodon bastiodon
# claydol claydol
# dragonair dragonair
# litleo litleo
# dedenne dedenne
# wishiwashi wishiwashi
# pidgey pidgey
# shedinja shedinja
# persian persian
# heracross heracross
# gulpin gulpin
# skuntank skuntank
# hoothoot hoothoot
# primarina primarina
# doublade doublade
# chimecho chimecho
# glalie glalie
# timburr timburr
# groudon groudon
# vileplume vileplume
# fletchinder fletchinder
# shinx shinx
# meloetta meloetta
# delibird delibird
# minior minior
# nosepass nosepass
# cubone cubone
# elgyem elgyem
# toxtricity toxtricity
# ninetales ninetales
# machamp machamp
# shieldon shieldon
# carnivine carnivine
# giratina giratina
# bounsweet bounsweet
# stakataka stakataka
# muk muk
# doduo doduo
# pinsir pinsir
# cubchoo cubchoo
# meditite meditite
# vespiquen vespiquen
# tympole tympole
# medicham medicham
# pineco pineco
# staryu staryu
# necrozma necrozma
# nidoking nidoking
# houndoom houndoom
# igglybuff igglybuff
# gastrodon gastrodon
# swablu swablu
# loudred loudred
# victini victini
# leavanny leavanny
# bonsly bonsly
# clawitzer clawitzer
# azurill azurill
# teddiursa teddiursa
# poliwhirl poliwhirl
# pangoro pangoro
# poliwrath poliwrath
# croagunk croagunk
# marshtomp marshtomp
# mareep mareep
# dubwool dubwool
# gyarados gyarados
# klefki klefki
# sobble sobble
# cottonee cottonee
# gloom gloom
# arctozolt arctozolt
# lurantis lurantis
# kartana kartana
# deerling deerling
# rhyhorn rhyhorn
# woobat woobat
# togetic togetic
# thwackey thwackey
# jynx jynx
# slowking slowking
# phantump phantump
# whiscash whiscash
# mr-mime mr. mime
# kingdra kingdra
# palkia palkia
# inteleon inteleon
# roselia roselia
# vigoroth vigoroth
# carracosta carracosta
# drampa drampa
# mismagius mismagius
# voltorb voltorb
# dragonite dragonite
# cranidos cranidos
# cherrim cherrim
# heatran heatran
# xurkitree xurkitree
# marshadow marshadow
# dracozolt dracozolt
# psyduck psyduck
# audino audino
# buizel buizel
# cosmog cosmog
# bunnelby bunnelby
# wobbuffet wobbuffet
# sinistea sinistea
# golbat golbat
# celebi celebi
# watchog watchog
# kabutops kabutops
# barbaracle barbaracle
# seaking seaking
# swellow swellow
# porygon-z porygon-z
# snivy snivy
# servine servine
# vikavolt vikavolt
# crobat crobat
# arcanine arcanine
# mewtwo mewtwo
# corsola corsola
# celesteela celesteela
# grotle grotle
# magmortar magmortar
# skitty skitty
# nidoqueen nidoqueen
# bellossom bellossom
# malamar malamar
# drowzee drowzee
# bidoof bidoof
# larvitar larvitar
# frogadier frogadier
# jumpluff jumpluff
# purrloin purrloin
# mareanie mareanie
# fennekin fennekin
# sneasel sneasel
# dragapult dragapult
# aromatisse aromatisse
# linoone linoone
# honchkrow honchkrow
# yanmega yanmega
# lampent lampent
# mudsdale mudsdale
# entei entei
# tsareena tsareena
# urshifu urshifu
# bouffalant bouffalant
# pidgeot pidgeot
# kangaskhan kangaskhan
# melmetal melmetal
# arctovish arctovish
# musharna musharna
# illumise illumise
# baltoy baltoy
# grimer grimer
# smeargle smeargle
# vulpix vulpix
# octillery octillery
# wormadam wormadam
# tirtouga tirtouga
# breloom breloom
# klang klang
# goodra goodra
# staravia staravia
# trapinch trapinch
# cacnea cacnea
# magcargo magcargo
# mimikyu mimikyu
# oshawott oshawott
# kricketune kricketune
# mesprit mesprit
# roggenrola roggenrola
# whirlipede whirlipede
# clefable clefable
# whimsicott whimsicott
# avalugg avalugg
# dratini dratini
# spiritomb spiritomb
# grimmsnarl grimmsnarl
# rapidash rapidash
# ledyba ledyba
# slaking slaking
# jigglypuff jigglypuff
# tapu-koko tapu koko
# paras paras
# poochyena poochyena
# starmie starmie
# huntail huntail
# reuniclus reuniclus
# caterpie caterpie
# shaymin shaymin
# swirlix swirlix
# weavile weavile
# murkrow murkrow
# plusle plusle
# crabrawler crabrawler
# milcery milcery
# sylveon sylveon
# shellos shellos
# mightyena mightyena
# horsea horsea
# shiftry shiftry
# cobalion cobalion
# crabominable crabominable
# porygon porygon
# hariyama hariyama
# tynamo tynamo
# copperajah copperajah
# blipbug blipbug
# seadra seadra
# rolycoly rolycoly
# mothim mothim
# vullaby vullaby
# totodile totodile
# gothitelle gothitelle
# samurott samurott
# dugtrio dugtrio
# axew axew
# glameow glameow
# lanturn lanturn
# frosmoth frosmoth
# ho-oh ho-oh
# yamper yamper
# duskull duskull
# zapdos zapdos
# zarude zarude
# grookey grookey
# pancham pancham
# squirtle squirtle
# slowbro slowbro
# stantler stantler
# meltan meltan
# ivysaur ivysaur
# gabite gabite
# decidueye decidueye
# gengar gengar
# nidorino nidorino
# azumarill azumarill
# torterra torterra
# magnemite magnemite
# gogoat gogoat
# thievul thievul
# dewgong dewgong
# dusknoir dusknoir
# mankey mankey
# klinklang klinklang
# torkoal torkoal
# tornadus tornadus
# goomy goomy
# bergmite bergmite
# silcoon silcoon
# froslass froslass
# spoink spoink
# minun minun
# zeraora zeraora
# spearow spearow
# stufful stufful
# poliwag poliwag
# donphan donphan
# arceus arceus
# noibat noibat
# cinccino cinccino
# toucannon toucannon
# blaziken blaziken
# gourgeist gourgeist
# drakloak drakloak
# cryogonal cryogonal
# shuckle shuckle
# slugma slugma
# beartic beartic
# regice regice
# heatmor heatmor
# hydreigon hydreigon
# guzzlord guzzlord
# staraptor staraptor
# mudkip mudkip
# mamoswine mamoswine
# galvantula galvantula
# onix onix
# regigigas regigigas
# heliolisk heliolisk
# carbink carbink
# dhelmise dhelmise
# dottler dottler
# unown unown
# furret furret
# whismur whismur
# togepi togepi
# barboach barboach
# morelull morelull
# pheromosa pheromosa
# cacturne cacturne
# geodude geodude
# comfey comfey
# uxie uxie
# pelipper pelipper
# simisear simisear
# espeon espeon
# tapu-lele tapu lele
# salazzle salazzle
# sunflora sunflora
# goldeen goldeen
# tentacool tentacool
# grubbin grubbin
# impidimp impidimp
# jellicent jellicent
# slowpoke slowpoke
# weedle weedle
# regieleki regieleki
# cinderace cinderace
# yamask yamask
# fearow fearow
# cufant cufant
# metagross metagross
# xatu xatu
# shuppet shuppet
# wailmer wailmer
# parasect parasect
# purugly purugly
# stunfisk stunfisk
# chingling chingling
# bronzor bronzor
# thundurus thundurus
# bagon bagon
# solosis solosis
# articuno articuno
# haunter haunter
# skiddo skiddo
# pansear pansear
# garbodor garbodor
# anorith anorith
# flabebe flabébé
# turtonator turtonator
# hakamo-o hakamo-o
# naganadel naganadel
# sirfetchd sirfetch'd
# typhlosion typhlosion
# trevenant trevenant
# quagsire quagsire
# porygon2 porygon2
# rowlet rowlet
# flapple flapple
# ditto ditto
# alomomola alomomola
# rockruff rockruff
# wingull wingull
# krokorok krokorok
# foongus foongus
# hitmonlee hitmonlee
# duosion duosion
# eelektrik eelektrik
# magmar magmar
# mawile mawile
# rookidee rookidee
# escavalier escavalier
# nincada nincada
# farfetch'd farfetch'd
# skiploom skiploom
# walrein walrein
# cradily cradily
# sawk sawk
# fomantis fomantis
# buzzwole buzzwole
# seviper seviper
# aerodactyl aerodactyl
# kecleon kecleon
# rotom rotom
# golisopod golisopod
# magby magby
# weezing weezing
# excadrill excadrill
# finneon finneon
# lickilicky lickilicky
# diglett diglett
# omanyte omanyte
# snubbull snubbull
# lilligant lilligant
# sandshrew sandshrew
# lapras lapras
# raikou raikou
# drapion drapion
# duraludon duraludon
# dewott dewott
# helioptile helioptile
# exeggutor exeggutor
# golduck golduck
# sliggoo sliggoo
# mandibuzz mandibuzz
# buneary buneary
# mantine mantine
# phanpy phanpy
# corviknight corviknight
# morgrem morgrem
# drifloon drifloon
# eternatus eternatus
# chatot chatot
# throh throh
# komala komala
# mime-jr mime jr.
# burmy burmy
# clamperl clamperl
# aron aron
# altaria altaria
# steenee steenee
# wimpod wimpod
# spectrier spectrier
# type-null type: null
# nidorina nidorina
# jirachi jirachi
# araquanid araquanid
# slakoth slakoth
# grovyle grovyle
# tentacruel tentacruel
# snover snover
# hippopotas hippopotas
# sawsbuck sawsbuck
# torracat torracat
# wooloo wooloo
# toxicroak toxicroak
# wartortle wartortle
# spheal spheal
# noivern noivern
# sharpedo sharpedo
# skrelp skrelp
# scyther scyther
# rhydon rhydon
# tepig tepig
# liepard liepard
# pignite pignite
# latios latios
# alakazam alakazam
# oricorio oricorio
# swinub swinub
# clauncher clauncher
# stonjourner stonjourner
# sentret sentret
# girafarig girafarig
# gigalith gigalith
# feebas feebas
# wynaut wynaut
# sandile sandile
# probopass probopass
# skwovet skwovet
# omastar omastar
# ampharos ampharos
# greninja greninja
# beautifly beautifly
# luxio luxio
# tyrantrum tyrantrum
# zigzagoon zigzagoon
# klink klink
# ursaring ursaring
# shiinotic shiinotic
# exeggcute exeggcute
# latias latias
# floette floette
# lycanroc lycanroc
# koffing koffing
# kyurem kyurem
# eiscue eiscue
# glastrier glastrier
# popplio popplio
# tangrowth tangrowth
# wooper wooper
# swanna swanna
# electabuzz electabuzz
# pincurchin pincurchin
# suicune suicune
# electrike electrike
# cosmoem cosmoem
# hitmontop hitmontop
# rampardos rampardos
# primeape primeape
# zweilous zweilous
# ralts ralts
# dustox dustox
# camerupt camerupt
# kakuna kakuna
# passimian passimian
# karrablast karrablast
# croconaw croconaw
# litten litten
# rillaboom rillaboom
# sandaconda sandaconda
# dusclops dusclops
# cloyster cloyster
# kirlia kirlia
# oddish oddish
# lombre lombre
# chansey chansey
# grapploct grapploct
# seel seel
# beheeyem beheeyem
# lairon lairon
# durant durant
# starly starly
# rufflet rufflet
# deoxys deoxys
# lugia lugia
# marowak marowak
# braixen braixen
# boltund boltund
# raichu raichu
# riolu riolu
# blastoise blastoise
# dwebble dwebble
# scrafty scrafty
# appletun appletun
# pikachu pikachu
# pichu pichu
# meganium meganium
# kabuto kabuto
# volcanion volcanion
# venusaur venusaur
# flygon flygon
# silvally silvally
# happiny happiny
# hatenna hatenna
# wurmple wurmple
# gothita gothita
# lumineon lumineon
# archen archen
# arbok arbok
# empoleon empoleon
# unfezant unfezant
# archeops archeops
# spewpa spewpa
# sandslash sandslash
# vanillish vanillish
# bruxish bruxish
# alcremie alcremie
# minccino minccino
# pikipek pikipek
# monferno monferno
# metapod metapod
# cramorant cramorant
# jolteon jolteon
# perrserker perrserker
# oranguru oranguru
# elekid elekid
# houndour houndour
# zamazenta zamazenta
# chandelure chandelure
# keldeo keldeo
# mienfoo mienfoo
# solrock solrock
# pyukumuku pyukumuku
# seismitoad seismitoad
# sceptile sceptile
# fletchling fletchling
# scorbunny scorbunny
# flaaffy flaaffy
# torchic torchic
# litwick litwick
# ferroseed ferroseed
# weepinbell weepinbell
# morpeko morpeko
# bibarel bibarel
# terrakion terrakion
# granbull granbull
# dartrix dartrix
# gorebyss gorebyss
# electivire electivire
# magearna magearna
# dodrio dodrio
# chikorita chikorita
# cursola cursola
# lileep lileep
# gossifleur gossifleur
# machoke machoke
# druddigon druddigon
# xerneas xerneas
# skarmory skarmory
# ariados ariados
# lucario lucario
# ferrothorn ferrothorn
# turtwig turtwig
# hawlucha hawlucha
# centiskorch centiskorch
# obstagoon obstagoon
# regidrago regidrago
# charmeleon charmeleon
# hoopa hoopa
# cyndaquil cyndaquil
# metang metang
# golem golem
# carvanha carvanha
# tauros tauros
# steelix steelix
# poipole poipole
# swampert swampert
# gardevoir gardevoir
# accelgor accelgor
# nickit nickit
# raboot raboot
# krabby krabby
# milotic milotic
# gastly gastly
# meowstic meowstic
# tyranitar tyranitar
# joltik joltik
# toxapex toxapex
# maractus maractus
# zoroark zoroark
# taillow taillow
# cofagrigus cofagrigus
# hatterene hatterene
# crustle crustle
# kricketot kricketot
# tyrunt tyrunt
# raticate raticate
# panpour panpour
# herdier herdier
# flareon flareon
# petilil petilil
# aurorus aurorus
# vaporeon vaporeon
# binacle binacle
# snorunt snorunt
# chesnaught chesnaught
# diggersby diggersby
# charizard charizard
# nidoran-f nidoran♀
# victreebel victreebel
# eelektross eelektross
# roserade roserade
# tranquill tranquill
# zekrom zekrom
# kadabra kadabra
# luxray luxray
# sudowoodo sudowoodo
# luvdisc luvdisc
# delphox delphox
# fraxure fraxure
# darumaka darumaka
# mudbray mudbray
# sewaddle sewaddle
# prinplup prinplup
# charmander charmander
# kommo-o kommo-o
# falinks falinks
# cleffa cleffa
# sableye sableye
# aipom aipom
# pansage pansage
# magnezone magnezone
# dreepy dreepy
# swalot swalot
# bellsprout bellsprout
# pumpkaboo pumpkaboo
# kingler kingler
# pupitar pupitar
# larvesta larvesta
# volbeat volbeat
# leafeon leafeon
# ducklett ducklett
# incineroar incineroar
# treecko treecko
# amaura amaura
# shellder shellder
# tyrogue tyrogue
# cascoon cascoon
# bewear bewear
# genesect genesect
# magikarp magikarp
# armaldo armaldo
# skorupi skorupi
# budew budew
# yungoos yungoos
# calyrex calyrex
# tapu-fini tapu fini
# tangela tangela
# surskit surskit
# meowth meowth
# barraskewda barraskewda
# hitmonchan hitmonchan
# froakie froakie
# scizor scizor
# gligar gligar
# mew mew
# drednaw drednaw
# indeedee indeedee
# ribombee ribombee
# phione phione
# quilava quilava
# feraligatr feraligatr
# zygarde zygarde
# ludicolo ludicolo
# jangmo-o jangmo-o
# dunsparce dunsparce
# gallade gallade
# magneton magneton
# tapu-bulu tapu bulu
# garchomp garchomp
# swadloon swadloon
# vanilluxe vanilluxe
# sunkern sunkern
# ponyta ponyta
# noctowl noctowl
# hippowdon hippowdon
# sandygast sandygast
# drifblim drifblim
# scraggy scraggy
# palossand palossand
# florges florges
# shroomish shroomish
# munna munna
# clobbopus clobbopus
# pawniard pawniard
# lunatone lunatone
# hattrem hattrem
# mr-rime mr. rime
# frillish frillish
# conkeldurr conkeldurr
# lickitung lickitung
# togedemaru togedemaru
# basculin basculin
# corphish corphish
# lillipup lillipup
# landorus landorus
# chinchou chinchou
# simisage simisage
# chewtle chewtle
# emboar emboar
# butterfree butterfree
# patrat patrat
# vibrava vibrava
# carkol carkol
# blitzle blitzle
# reshiram reshiram
# lotad lotad
# snom snom
# vanillite vanillite
# hypno hypno
# nihilego nihilego
# dialga dialga
# castform castform
# banette banette
# bisharp bisharp
# vivillon vivillon
# ambipom ambipom
# diancie diancie
# wigglytuff wigglytuff
# dewpider dewpider
# haxorus haxorus
# coalossal coalossal
# deino deino
# braviary braviary
# pachirisu pachirisu
# orbeetle orbeetle
# boldore boldore

# %%
temp_table['Alt. Name'] = temp_table['Name'].replace({good: bad for good, bad in zip(names_list, bad_names_list)})

# %%
temp_table[temp_table['Name'] == 'nidoran-m']
# Out:
#       Lv.          Move    Type      Cat. Power Acc.       Name  TM Method  \
# 546   1.0          Leer  Normal    status     —  100  nidoran-m NaN    NaN
# 547   1.0  Poison Sting  Poison  physical    15  100  nidoran-m NaN    NaN
# 548   5.0          Peck  Flying  physical    35  100  nidoran-m NaN    NaN
# 549  10.0  Focus Energy  Normal    status     —    —  nidoran-m NaN    NaN
# 550  15.0   Fury Attack  Normal  physical    15   85  nidoran-m NaN    NaN
# ..    ...           ...     ...       ...   ...  ...        ...  ..    ...
# 635   NaN  Toxic Spikes  Poison    status     —    —  nidoran-m NaN    NaN
# 636   NaN    Poison Jab  Poison  physical    80  100  nidoran-m NaN    NaN
# 637   NaN   Earth Power  Ground   special    90  100  nidoran-m NaN    NaN
# 638   NaN     Drill Run  Ground  physical    80   95  nidoran-m NaN    NaN
# 639   NaN  Venom Drench  Poison    status     —  100  nidoran-m NaN    NaN
#
#        TR Details Alt. Name
# 546   NaN     NaN  nidoran♂
# 547   NaN     NaN  nidoran♂
# 548   NaN     NaN  nidoran♂
# 549   NaN     NaN  nidoran♂
# 550   NaN     NaN  nidoran♂
# ..    ...     ...       ...
# 635  54.0     NaN  nidoran♂
# 636  57.0     NaN  nidoran♂
# 637  67.0     NaN  nidoran♂
# 638  87.0     NaN  nidoran♂
# 639  91.0     NaN  nidoran♂
#
# [94 rows x 12 columns]

# %%
temp_table.to_csv('../data/move_data.csv')
